# %%
#installing and importing the libraries

import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt  

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
#loading the dataset
resume_dataset = pd.read_csv('D:/MPS - Analytics/EAI 6000/Group Project/UpdatedResumeDataSet.csv',encoding='utf-8')

# %%
#displaying the first 10 values of dataset
resume_dataset.head(10)
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# 5  Data Science  SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# 6  Data Science  Skills â¢ Python â¢ Tableau â¢ Data Visuali...
# 7  Data Science  Education Details \r\n B.Tech   Rayat and Bahr...
# 8  Data Science  Personal Skills â¢ Ability to quickly grasp t...
# 9  Data Science  Expertise â Data and Quantitative Analysis â...

# %%
#displaying the last 10 values of dataset
resume_dataset.tail(10)
# Out:
#     Category                                             Resume
# 952  Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 953  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 954  Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
# 955  Testing  â¢ Good logical and analytical skills â¢ Pos...
# 956  Testing  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 957  Testing  Computer Skills: â¢ Proficient in MS office (...
# 958  Testing  â Willingness to accept the challenges. â ...
# 959  Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961  Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...

# %%
#descriptive analysis


#displaying the number of rows and columns of the dataset
print("Total number of Rows and Columns:",resume_dataset.shape)
# Out:
# Total number of Rows and Columns: (962, 2)

# %%
#descriptive analysis


#displaying the data field values
print("Column Names:",resume_dataset.columns)
# Out:
# Column Names: Index(['Category', 'Resume'], dtype='object')

# %%
#descriptive analysis


#displaying the data types
print("Data types:\n",resume_dataset.dtypes)
# Out:
# Data types:
#  Category    object
# Resume      object
# dtype: object

# %%
#descriptive analysis


#information about the dataframe
resume_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  962 non-null    object
#  1   Resume    962 non-null    object
# dtypes: object(2)
# memory usage: 15.2+ KB

# %%
#statistical analysis 


#describing the dataset
resume_dataset.describe()
# Out:
#               Category                                             Resume
# count              962                                                962
# unique              25                                                166
# top     Java Developer  Technical Skills Web Technologies: Angular JS,...
# freq                84                                                 18

# %%
#data profiling

resumedata_profile = resume_dataset.profile_report(title='Resume Data Analysis Report', explorative =True)
resumedata_profile


#NOTE: 
#The Data Profiling report generated is saved in a HTML file, and attached separetely.
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-13 18:16:07.870147&quot;&gt;&lt;title&gt;Resume Data Analysis Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#save the data profile report as html file

resumedata_profile.to_file(output_file="Resume Data Analysis Report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#installing the libraries

# !pip install pdfminer
# !pip install pdfminer.six
# Out:
# ...
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.7
#     Uninstalling cryptography-3.4.7:
#       Successfully uninstalled cryptography-3.4.7
# ...

# %%
#importing the libraries
import pdfminer 
from pdfminer.high_level import extract_text


#checking for the version of pdfminer
print(pdfminer.__version__)
# Out:
# 20191125

# %%
# Extracting text from pdf files

def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)
 
    
    
if __name__ == '__main__':
    print(extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf"))
# Out:
# FA R A H   M A R T I N
#
# DATA ANALYST
#
# CONTACT
#
# farahmartin@email.com
# (123) 456-7890
# Brooklyn, NY
# LinkedIn
#
# EDUCATION
# B.S.
# Mathematics and
# Economics
# University of Pittsburgh
# September 2010 - April 2014
# Pittsburgh, PA
#
# SKILLS
# SQL
# Excel/ Google Sheets
# A/B Testing &
# Experimentation
# Tableau
# Python (Pandas, Scikit-learn)
# Google Analytics
# Leadership Experience
#
# WORK EXPERIENCE
# Data Analyst
# Fountain House
# May 2018 - current / New York, NY
#
# · Built out the data and reporting infrastructure from the
# ground up using Tableau and SQL to provide real-time insights
# into the product, marketing funnels, and business KPIs
#
# · Designed and implemented A/B experiments for products to
# improve the conversion rate by 19 basis points and reduce
# churn by 12 basis points
#
# customer value by 25%
#
# · Implemented long-term pricing experiment that improved
# · Built operational reporting in Tableau to ﬁnd areas of
#
# ...

# %%
#Extracting email addresses from resumes


EMAIL_REG = re.compile(r'[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+')
 
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)
  
def extract_emails(resume_text):
    return re.findall(EMAIL_REG, resume_text)
 
if __name__ == '__main__':
    text = extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf")
    emails = extract_emails(text)
 
    if emails:
        print(emails[0])
# Out:
# farahmartin@email.com

# %%
#nltk library

import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rramb\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\rramb\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\rramb\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\rramb\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
#Extracting names from resumes

def extract_text_from_pdf(pdf_path):
    txt = extract_text(pdf_path)
    if txt:
        return txt.replace('\t', ' ')
    return None 
 
def extract_names(txt):
    person_names = []
 
    for sent in nltk.sent_tokenize(txt):
        for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
            if hasattr(chunk, 'label') and chunk.label() == 'PERSON':
                person_names.append(
                    ' '.join(chunk_leave[0] for chunk_leave in chunk.leaves())
                )
 
    return person_names
  
if __name__ == '__main__':
    text = extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf")
    names = extract_names(text)
    
    #print(text)
    print(names)
    
#    if names:
#        print(names[0]) 
        

#It was noticed that the nltk's person name detection algorithm does not give correct results
# Out:
# ['Pandas', 'Google Analytics Leadership Experience', 'Tableau', 'Data Analyst Wavely', 'Google Sheets', 'Product Modeling Analyst Geico', 'Python', 'Excel']

# %%
#installing the library

# !pip install nameparser

# %%
#Extracting names from resumes (with a different Library)

from nameparser.parser import HumanName

resume_path = "D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf"

def extract_text_from_pdf(pdf_path):
    txt = extract_text(pdf_path)
    if txt:
        return txt.replace('\t', ' ')
    return None 



def get_human_names(text):
    tokens = nltk.tokenize.word_tokenize(text)
    pos = nltk.pos_tag(tokens)
    sentt = nltk.ne_chunk(pos, binary = False)
    person_list = []
    person = []
    name = ""
    for subtree in sentt.subtrees(filter=lambda t: t.label() == 'PERSON'):
        for leaf in subtree.leaves():
            person.append(leaf[0])
        if len(person) > 1: #avoid grabbing lone surnames
            for part in person:
                name += part + ' '
            if name[:-1] not in person_list:
                person_list.append(name[:-1])
            name = ''
        person = []

    return (person_list)

document = extract_text_from_pdf(resume_path)
names = get_human_names(document)
print(names[0])

#for name in names: 
#    last_first = HumanName(name).first + ', ' + HumanName(name).last
#    print(last_first)
# Out:
# Google Analytics Leadership Experience

# %%
# Extracting Phone Number

import subprocess  # noqa: S404
 
PHONE_REG = re.compile(r'[\+\(]?[1-9][0-9 .\-\(\)]{8,}[0-9]')
 

def extract_text_from_pdf(pdf_path):
    txt = extract_text(pdf_path)
    if txt:
        return txt.replace('\t', ' ')
    return None 


def extract_phone_number(resume_text):
    phone = re.findall(PHONE_REG, resume_text)
 
    if phone:
        number = ''.join(phone[0])
 
        if resume_text.find(number) :#and len(number) ==16:
            return number
    return None
 
 
if __name__ == '__main__':
    text = extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf")
    
    phone_number = extract_phone_number(text)
 
    print(phone_number)  # noqa: T001
# Out:
# (123) 456-7890

# %%
# Extracting skills from resume 

nltk.download('stopwords')
 
# you may read the database from a csv file or some other database
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'excel',
    'English',
]
  
def extract_text_from_pdf(pdf_path):
    txt = extract_text(pdf_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
  
def extract_skills(input_text):
    stop_words = set(nltk.corpus.stopwords.words('english'))
    word_tokens = nltk.tokenize.word_tokenize(input_text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w not in stop_words]
 
    # remove the punctuation
    filtered_tokens = [w for w in word_tokens if w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens, 2, 3)))
 
    # we create a set to keep the results in.
    found_skills = set()
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB:
            found_skills.add(token)
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB:
            found_skills.add(ngram)
 
    return found_skills
  
if __name__ == '__main__':
    text = extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf")
    skills = extract_skills(text)
 
    print(skills)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rramb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'Excel', 'Python'}

# %%
#Extracting education and schools from resume
 
RESERVED_WORDS = ['school','college','univers','academy','faculty','institute',
                  'faculdades','Schola','schule','lise','lyceum','lycee',
                  'polytechnic','kolej','ünivers','okul']
  
def extract_text_from_pdf(pdf_path):
    txt = extract_text(pdf_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
  
def extract_education(input_text):
    organizations = []
 
    # first get all the organization names using nltk
    for sent in nltk.sent_tokenize(input_text):
        for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
            if hasattr(chunk, 'label') and chunk.label() == 'ORGANIZATION':
                organizations.append(' '.join(c[0] for c in chunk.leaves()))
 
    # we search for each bigram and trigram for reserved words
    # (college, university etc...)
    education = set()
    for org in organizations:
        for word in RESERVED_WORDS:
            if org.lower().find(word) :#& gt== 0:
                education.add(org)
 
    return education
  
if __name__ == '__main__':
    text = extract_text_from_pdf("D:/MPS - Analytics/EAI 6000/Group Project/Dataset/data-analyst-resume-example.pdf")
    education_information = extract_education(str(text))
 
    print(education_information)
# Out:
# {'SQL', 'YoY', 'Washington D.C.', 'SEO', 'Pittsburgh', 'Economics University', 'KPIs', 'Experimentation Tableau Python', 'NY', 'House', 'PA'}

# %%
#data cleaning for the dataset


#checking for null values in the each column of the dataset
for x in range(2):
    print("%-45s %10d" % (resume_dataset.columns.values[x], resume_dataset.iloc[:,x].isna().sum()))
print()
# Out:
# Category                                               0
# Resume                                                 0

# %%
#displaying the unqiue categories

print(resume_dataset['Category'].unique())
# Out:
# ['Data Science' 'HR' 'Advocate' 'Arts' 'Web Designing'
#  'Mechanical Engineer' 'Sales' 'Health and fitness' 'Civil Engineer'
#  'Java Developer' 'Business Analyst' 'SAP Developer' 'Automation Testing'
#  'Electrical Engineering' 'Operations Manager' 'Python Developer'
#  'DevOps Engineer' 'Network Security Engineer' 'PMO' 'Database' 'Hadoop'
#  'ETL Developer' 'DotNet Developer' 'Blockchain' 'Testing']

# %%
#displaying the number of records for each distinct category

print(resume_dataset['Category'].value_counts())
# Out:
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# ETL Developer                40
# Data Science                 40
# Blockchain                   40
# Mechanical Engineer          40
# Sales                        40
# Operations Manager           40
# Arts                         36
# Database                     33
# PMO                          30
# Electrical Engineering       30
# Health and fitness           30
# DotNet Developer             28
# Business Analyst             28
# Automation Testing           26
# Network Security Engineer    25
# Civil Engineer               24
# SAP Developer                24
# Advocate                     20
# Name: Category, dtype: int64

# %%
#data visualization

plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
plt.title("Frequency Count of each Category")
plot = sns.countplot(x="Category", data=resume_dataset)

# %%
#describing new column in dataset

resume_dataset['Cleaned_Resume'] = ''
resume_dataset.head(5)
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#   Cleaned_Resume
# 0
# 1
# 2
# 3
# 4

# %%
#cleaning resume text function

def cleaning_resumeData(resumeText):

    resumeText = re.sub('http\S+\s*', ' ', resumeText)  # remove URLs
    resumeText = re.sub('RT|cc', ' ', resumeText)  # remove RT and cc
    resumeText = re.sub('#\S+', '', resumeText)  # remove hashtags
    resumeText = re.sub('@\S+', '  ', resumeText)  # remove mentions
    resumeText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', resumeText)  # remove punctuations
    resumeText = re.sub(r'[^\x00-\x7f]',r' ', resumeText) 
    resumeText = re.sub('\s+', ' ', resumeText)  # remove extra whitespace
    
    return resumeText

# %%
#main function

result = []
for i in resume_dataset['Resume']:
    result.append(cleaning_resumeData(i))

resume_dataset['Cleaned_Resume'] = result    

print("Resume Data is cleaned!")
# Out:
# Resume Data is cleaned!

# %%
#displaying starting rows of cleaned data
resume_dataset.head(10)
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# 5  Data Science  SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# 6  Data Science  Skills â¢ Python â¢ Tableau â¢ Data Visuali...
# 7  Data Science  Education Details \r\n B.Tech   Rayat and Bahr...
# 8  Data Science  Personal Skills â¢ Ability to quickly grasp t...
# 9  Data Science  Expertise â Data and Quantitative Analysis â...
#
#                                       Cleaned_Resume
# 0  Skills Programming Languages Python pandas num...
# 1  Education Details May 2013 to May 2017 B E UIT...
# 2  Areas of Interest Deep Learning Control System...
# ...

# %%
#displaying ending rows of cleaned data
resume_dataset.tail(10)
# Out:
#     Category                                             Resume  \
# 952  Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 953  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 954  Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
# 955  Testing  â¢ Good logical and analytical skills â¢ Pos...
# 956  Testing  COMPUTER PROFICIENCY â¢ Basic: MS-Office (Pow...
# 957  Testing  Computer Skills: â¢ Proficient in MS office (...
# 958  Testing  â Willingness to accept the challenges. â ...
# 959  Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961  Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
#                                         Cleaned_Resume
# 952  PERSONAL SKILLS Quick learner Eagerness to lea...
# 953  COMPUTER SKILLS SOFTWARE KNOWLEDGE MS Power Po...
# 954  Skill Set OS Windows XP 7 8 8 1 10 Database MY...
# ...

# %%
#labeling the categories column into numerical values

labelencoder = LabelEncoder()

resume_dataset['Category_Labels']  = labelencoder.fit_transform(resume_dataset["Category"])
resume_dataset
# Out:
#          Category                                             Resume  \
# 0    Data Science  Skills * Programming Languages: Python (pandas...
# 1    Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4    Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..            ...                                                ...
# 957       Testing  Computer Skills: â¢ Proficient in MS office (...
# 958       Testing  â Willingness to accept the challenges. â ...
# 959       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
#                                         Cleaned_Resume  Category_Labels
# ...

# %%
#word vectorization

word_vectorizer = TfidfVectorizer(
        sublinear_tf=True,
        stop_words='english')

# %%
#getting word vectorization

requiredText = resume_dataset['Cleaned_Resume'].values
requiredTarget = resume_dataset['Category_Labels'].values

word_vectorizer.fit(requiredText)
WordFeatures = word_vectorizer.transform(requiredText)

WordFeatures
# Out:
# <962x7351 sparse matrix of type '<class 'numpy.float64'>'
# 	with 164261 stored elements in Compressed Sparse Row format>

# %%
#model building

X_train,X_test,y_train,y_test = train_test_split(WordFeatures,requiredTarget,random_state=42, test_size=0.3)

print(X_train.shape)
print(X_test.shape)
# Out:
# (673, 7351)
# (289, 7351)

# %%
#model building
#Kneighbors Classifier

kneighbors_classifier = OneVsRestClassifier(KNeighborsClassifier())
kneighbors_classifier.fit(X_train, y_train)
prediction_result1 = kneighbors_classifier.predict(X_test)


print("The predicted labels/classification is:\n")
prediction_result1
# Out:
# The predicted labels/classification is:
# array([15, 15, 15, 13, 14, 17, 16,  2,  0, 22, 13, 12, 16, 23, 20,  5,  6,
#         4, 10,  9, 19,  1, 10, 23, 23, 21, 22, 22,  2, 12, 18,  1,  8, 24,
#        11, 23,  6, 12, 24,  8, 18,  6,  8, 19, 24, 23, 21,  1, 15,  4, 15,
#        22, 11,  5, 15, 13,  1, 19,  5, 12, 22, 22, 20, 24, 21, 18, 12, 10,
#        10, 20, 10,  8,  9, 21, 17, 21,  0, 17, 16, 14, 15, 11, 11,  8, 20,
#         3, 19,  8,  0,  2,  9, 10,  2, 23, 20, 20, 23, 12, 18, 12,  7, 16,
#         8, 14, 18,  3, 14, 19, 14, 22, 15, 18,  8,  2, 21, 18, 23, 10, 23,
#         5, 11, 15, 12,  3,  5,  3,  7, 12, 19,  8, 20, 19,  3, 15,  9, 19,
#         1, 23, 21,  5, 20, 15, 16,  7,  7,  8, 15, 18,  1, 15, 13, 20,  7,
#         4, 18, 11,  5, 15,  5, 12,  9, 22, 18, 21,  8, 23,  4, 12, 24, 16,
#        15, 22,  8, 22,  3, 16, 23, 23, 12,  7, 16, 18,  5,  3, 18,  8, 23,
#        23, 20, 21,  6,  7, 23,  2,  3, 18, 22,  1, 12, 13, 22, 12, 11, 23,
# ...

# %%
#predicted outcome on the test data

classification_outcome = pd.DataFrame()

classification_outcome['Actual Category_Label'] = ''
classification_outcome['Predicted Outcome'] = ''

classification_outcome['Actual Category_Label'] = y_test
classification_outcome['Predicted Outcome'] = prediction_result1

# %%
#predicted outcome on the test data - starting data

classification_outcome.head(10)
# Out:
#    Actual Category_Label  Predicted Outcome
# 0                     15                 15
# 1                     15                 15
# 2                     15                 15
# 3                     13                 13
# 4                     14                 14
# 5                     17                 17
# 6                     16                 16
# 7                      2                  2
# 8                      0                  0
# 9                     14                 22

# %%
#predicted outcome on the test data - end data

classification_outcome.tail(10)
# Out:
#      Actual Category_Label  Predicted Outcome
# 279                     18                 18
# 280                     18                 18
# 281                     20                 20
# 282                     23                 23
# 283                     13                 13
# 284                     10                 10
# 285                     20                 20
# 286                     11                 11
# 287                     23                 23
# 288                      4                  4

# %%
#accuracy of the model
#Kneighbors Classifier

print('Accuracy of KNeighbors Classifier on training set: {:.2f}'.format(kneighbors_classifier.score(X_train, y_train)))
print('Accuracy of KNeighbors Classifier on test set:     {:.2f}'.format(kneighbors_classifier.score(X_test, y_test)))

test_accuracy_KN = kneighbors_classifier.score(X_test, y_test)
test_accuracy_KN
# Out:
# Accuracy of KNeighbors Classifier on training set: 0.98
# Accuracy of KNeighbors Classifier on test set:     0.97
# 0.9688581314878892

# %%
#classification report of the model built
#Kneighbors Classifier

print("\n Classification report for classifier %s:\n%s\n" % (kneighbors_classifier, metrics.classification_report(y_test, prediction_result1)))
# Out:
#  Classification report for classifier OneVsRestClassifier(estimator=KNeighborsClassifier()):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         8
#            2       1.00      0.86      0.92         7
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        11
#            6       0.90      0.82      0.86        11
#            7       1.00      0.89      0.94         9
#            8       1.00      0.89      0.94        19
#            9       1.00      1.00      1.00        11
#           10       1.00      1.00      1.00         9
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00        17
#           13       1.00      1.00      1.00         9
#           14       1.00      0.70      0.82        10
# ...

# %%
#displaying the confusion matrix for KNeighbors model

confusionmatrix1 = confusion_matrix(y_test, prediction_result1)

plt.figure(figsize = (18,8))
ax = plt.subplot()
sns.heatmap(confusionmatrix2, annot=True, fmt='d', ax=ax);
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix (KNeighbors Model)');

# %%
#model building
#logistic regression

logisticregression_model = LogisticRegression()
logisticregression_model.fit(X_train, y_train)
prediction_result2 = logisticregression_model.predict(X_test)

print("The predicted labels/classification is:\n")
prediction_result2
# Out:
# The predicted labels/classification is:
# array([15, 15, 15, 13, 14, 17, 16,  2,  0, 14, 13, 12, 16, 23, 20,  5,  6,
#         4, 10,  9, 19,  1, 10, 23, 23,  6, 22, 22,  2, 12, 18,  1,  8, 24,
#        11, 23,  7, 12, 24,  8, 18,  6,  8, 19, 24, 23, 21,  1, 15,  4, 15,
#        22, 11,  5, 15, 13,  1, 19,  5, 12, 22, 22, 20, 24, 21, 18, 12, 10,
#        10, 20, 10,  8,  9, 21, 17, 21,  0, 17, 16, 14, 15, 11, 11,  8, 20,
#         3, 19,  8,  0,  2,  9, 10,  2, 23, 20, 20, 23, 12, 18, 12,  7, 16,
#         8, 14, 18,  3, 14, 19, 14, 14, 15, 18,  8,  2, 21, 18, 23, 10, 23,
#         5, 11, 15, 12,  3,  5,  3,  7, 12, 19,  8, 20, 23,  3, 15,  9, 19,
#         1, 23, 21,  5, 20, 15, 16,  7,  7,  8, 15, 18,  1, 15, 13, 20,  7,
#         4, 18, 11,  5, 15,  5, 12,  9, 22, 18, 21,  8, 23,  4, 12, 24, 16,
#        15, 22,  8, 22,  3, 16, 23, 23, 12,  7, 16, 18,  5,  3, 18,  8, 23,
#        23, 20,  6,  6,  7, 23,  2,  3, 18, 14,  1, 12, 13, 22, 12, 11, 23,
# ...

# %%
#predicted outcome on the test data

classification_outcome2 = pd.DataFrame()

classification_outcome2['Actual Category_Label'] = ''
classification_outcome2['Predicted Outcome'] = ''

classification_outcome2['Actual Category_Label'] = y_test
classification_outcome2['Predicted Outcome'] = prediction_result2

# %%
#predicted outcome on the test data - starting data

classification_outcome2.head(10)
# Out:
#    Actual Category_Label  Predicted Outcome
# 0                     15                 15
# 1                     15                 15
# 2                     15                 15
# 3                     13                 13
# 4                     14                 14
# 5                     17                 17
# 6                     16                 16
# 7                      2                  2
# 8                      0                  0
# 9                     14                 14

# %%
#predicted outcome on the test data - end data

classification_outcome.tail(10)
# Out:
#      Actual Category_Label  Predicted Outcome
# 279                     18                 18
# 280                     18                 18
# 281                     20                 20
# 282                     23                 23
# 283                     13                 13
# 284                     10                 10
# 285                     20                 20
# 286                     11                 11
# 287                     23                 23
# 288                      4                  4

# %%
#model building
#logistic regression

print('Accuracy of Logistic Regression on training set: {:.2f}'.format(logisticregression_model.score(X_train, y_train)))
print('Accuracy of Logistic Regression on test set:     {:.2f}'.format(logisticregression_model.score(X_test, y_test)))

test_accuracy_LR = logisticregression_model.score(X_test, y_test)
test_accuracy_LR
# Out:
# Accuracy of Logistic Regression on training set: 1.00
# Accuracy of Logistic Regression on test set:     0.99
# 0.9930795847750865

# %%
#model building
#logistic regression

print("\n Classification report %s:\n%s\n" % (logisticregression_model, metrics.classification_report(y_test, prediction_result2)))
# Out:
#  Classification report LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         7
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00         9
#            5       1.00      1.00      1.00        11
#            6       1.00      1.00      1.00        11
#            7       1.00      1.00      1.00         9
#            8       1.00      0.89      0.94        19
#            9       1.00      1.00      1.00        11
#           10       1.00      1.00      1.00         9
#           11       1.00      1.00      1.00         9
#           12       1.00      1.00      1.00        17
#           13       1.00      1.00      1.00         9
#           14       1.00      1.00      1.00        10
# ...

# %%
#displaying the confusion matrix for LR model

confusionmatrix2 = confusion_matrix(y_test, prediction_result2)

plt.figure(figsize = (18,8))
ax = plt.subplot()
sns.heatmap(confusionmatrix2, annot=True, fmt='d', ax=ax, cmap="YlGnBu");
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix (LR Model)');

# %%
#comparing accuracy of both models

print("Accuracy of the KNeigbors Model is:", test_accuracy_KN)
print("Accuracy of the Logistic Regression Model is:", test_accuracy_LR)
# Out:
# Accuracy of the KNeigbors Model is: 0.9688581314878892
# Accuracy of the Logistic Regression Model is: 0.9930795847750865
